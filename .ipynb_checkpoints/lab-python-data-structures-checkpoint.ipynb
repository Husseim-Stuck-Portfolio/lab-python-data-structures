# %% [markdown]
# # Lab | Data Structures

# %% [markdown]
# ## Exercise: Managing Customer Orders
#
# As part of a business venture, you are starting an online store that sells various products. To ensure smooth operations, you need to develop a program that manages customer orders and inventory.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a list called `products` that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".
#
# 2. Create an empty dictionary called `inventory`.
#
# 3. Ask the user to input the quantity of each product available in the inventory. Use the product names from the `products` list as keys in the `inventory` dictionary and assign the respective quantities as values.
#
# 4. Create an empty set called `customer_orders`.
#
# 5. Ask the user to input the name of three products that a customer wants to order (from those in the products list, meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". Add each product name to the `customer_orders` set.
#
# 6. Print the products in the `customer_orders` set.
#
# 7. Calculate the following order statistics:
#    - Total Products Ordered: The total number of products in the `customer_orders` set.
#    - Percentage of Products Ordered: The percentage of products ordered compared to the total available products.
#
#    Store these statistics in a tuple called `order_status`.
#
# 8. Print the order statistics using the following format:
#    ```
#    Order Statistics:
#    Total Products Ordered: <total_products_ordered>
#    Percentage of Products Ordered: <percentage_ordered>%
#    ```
#
# 9. Update the inventory by subtracting 1 from the quantity of each product. Modify the `inventory` dictionary accordingly.
#
# 10. Print the updated inventory, displaying the quantity of each product on separate lines.
#
# Solve the exercise by implementing the steps using the Python concepts of lists, dictionaries, sets, and basic input/output operations.

# %%
#step1 CREATING THE LIST
products = ["t-shirt", "mug", "hat", "book", "keychain"]
type(products)
print(products)

#step2 CREATING THE DICTIONARY
inventory = {}
type(inventory)
print(inventory)

#step3 - directory CREATING VALUES TO THE DICTIONARY KEYS
item_1 = input("provide quantity for" + products[0])
item_2 = input("provide quantity for" + products[1])
item_3 = input("provide quantity for" + products[2])
item_4 = input("provide quantity for" + products[3])
item_5 = input("provide quantity for" + products[4])

#3.1 CONNECTING THE KEYS TO THE VALUES

inventory[products[0]] = int(item_1)
inventory[products[1]] = int(item_2)
inventory[products[2]] = int(item_3)
inventory[products[3]] = int(item_4)
inventory[products[4]] = int(item_5)

print("updated :")
print(inventory)


#4 CREATING A SET 
customer_orders = set()


#5 STORING THE CUSTOMER ORDER IN A SET

wanted_item1 = input("please input products_1 that you want to order")
wanted_item2 = input("please input products_2 that you want to order")
wanted_item3 = input("please input products_3 that you want to order")


if wanted_item1 in products:
    customer_orders.add(wanted_item1)
if wanted_item2 in products:
    customer_orders.add(wanted_item2)
if wanted_item3 in products:
    customer_orders.add(wanted_item3)


#Step 6 PPRINT THE SET

print("you have selected", customer_orders)

#Step 7 STATISTICS OF THE CUSTOMER ORDER

total_products_ordered = len(customer_orders)
percentage_ordered = (total_products_ordered / len(products)) * 100
order_status = (total_products_ordered, percentage_ordered)    

print("total products:", total_products_ordered)
print("the percentage is:", percentage_ordered)
print(order_status)


#Step 8 PRINT OUT STATISTICS
print("total products ordered", order_status[0])
print("percentage of ordered items", order_status[1])



# Step 9 UPDATE THE INVENTORY WITH THE CUSTOMER REQUESTS


inventory[products[0]] = inventory[products[0]] -1
inventory[products[1]] = inventory[products[1]] -1
inventory[products[2]] = inventory[products[2]] -1
inventory[products[3]] = inventory[products[3]] -1
inventory[products[4]] = inventory[products[4]] -1


# Step 10 

print(inventory)
# Out:
# ['t-shirt', 'mug', 'hat', 'book', 'keychain']
# {}
# provide quantity fort-shirt 1
# provide quantity formug 2
# provide quantity forhat 3
# provide quantity forbook 4
# provide quantity forkeychain 5
# updated :
# {'t-shirt': 1, 'mug': 2, 'hat': 3, 'book': 4, 'keychain': 5}
# please input products_1 that you want to order hat
# please input products_2 that you want to order mug
# please input products_3 that you want to order plant
# you have selected {'hat', 'mug'}
# total products: 2
# the percentage is: 40.0
# (2, 40.0)
# total products ordered 2
# percentage of ordered items 40.0
# {'t-shirt': 0, 'mug': 1, 'hat': 2, 'book': 3, 'keychain': 4}
